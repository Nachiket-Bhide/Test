# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(-10,11)

# %%
def f(x):
    return x**2

# %%
plt.plot(x, f(x))

# %%
h = 0.00001
pt_x = 6
slope = (f(pt_x+h) - f(pt_x))/h
c = f(pt_x) - (slope*pt_x)
pt_y = (slope*pt_x) + c

y = (slope*x) + c
plt.figure()
plt.plot(x, f(x))
plt.plot(x, y, label=str("Derivative at point ({},{}) is {}".format(pt_x,pt_y,slope)))
plt.plot(pt_x, pt_y, marker='o')
plt.legend()

#Symbolic Derivative:
2*pt_x
# Out:
# 12
